# %% [markdown]
# # Punto_2_EDA

# %%
from IPython.display import Image, display

# %% [markdown]
# ## Descripción del EDA
# Para este caso, se utilizó la herramienta Dash para visualizar los datos de manera interactiva, dado el volumen y la variedad de archivos disponibles para el análisis. Esto permite observar el comportamiento real de los datos sin recurrir a agrupaciones forzadas, proporcionando una perspectiva más precisa y detallada de la información.

# %% [markdown]
# ## Link render
# https://render-practico-final-5.onrender.com

# %%
display(Image(filename='render1.png'))

# %%
display(Image(filename='render2.png'))

# %%
display(Image(filename='render3.png'))

# %%
display(Image(filename='render4.png'))
